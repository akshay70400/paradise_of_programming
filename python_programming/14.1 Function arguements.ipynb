# %% [markdown]
# ##### Local space and Global space in/out of Function

# %%
def my():
    x=10 #LOCAL SPACE
    print("Value of x in my function:", x)


#Programme Starts from line below:
x=5000
my() #GLOBAL SPACE
print("Value of x outside function: ",x)
# Out:
# Value of x in my function: 10
# Value of x outside function:  5000

# %%
def my():
#    x=10 #LOCAL SPACE
    print("Value of x in my in function:", x)

#Programme Starts from line below:
x=55555
my() #GLOBAL SPACE
print("Value of x outside function: ",x)
# Out:
# Value of x in my in function: 55555
# Value of x outside function:  55555

# %% [raw]
# #This gives error (as x is not defined in global space).
#
# def my():
# #    x=10 #LOCAL SPACE
#     print("Value of x in my function:", x)
#
# #Programme Starts from line below:
# my() #GLOBAL SPACE
# x=55555
# print("Value of x outside function: ",x)

# %% [markdown]
# ## Function Arguements
#
#     Default Arguements- assign default values if arg not passed
#
#     Keyword Arguements(kwarg)[x="ak"] -when there are many parameters and we do Not know the sequence of parameters
#
#     Arbitrary Arguements(*arg)[returns tuple] -not know how many arguments that will be passed
#
#     Arbitrary Keyword arguements(**kwarg)[returns dictionary] -not know how many keyword arguments that will be passed

# %% [markdown]
# ##### Default Arguements
# -All default arguements Sholud follow after non-default arguements
#
# -By default, a function must be called with the correct number of arguments.  (args)
# Meaning that if your function expects 2 arguments, you have to call the function with 2 arguments, not more, and not less.

# %%
def greet(name="Ajay", msg="Good Morning"):
    print("Hello,",name,msg)
greet()

# %%
def greet(name="Ajay", msg="Good Morning"):
    print("Hello,",name,msg)

x=input("Enter name: ")
m=input("Enter message: ")
greet(x,m)

# %%
#All default arguements Sholud follow after non-default arguements
def greet(name, msg="Good Morning"):
    print("Hello,",name,msg)

x=input("Enter name: ")
greet(x)
# Out:
# Enter name: kum
# Hello, kum Good Morning

# %% [raw]
# #ERROR:non-default argument follows default argument
#
# def greet(msg="Good Morning",name):
#     print("Hello,",name,msg)
#
# x=input("Enter name: ")
# greet(x,m)

# %% [markdown]
# ##### Keyword arguements
#
#     -You can also send arguments with the key = value syntax.
#     -This way the order of the arguments does not matter.
#     -@Usually when there are many parameters and we do Not know the sequence of parameters

# %%
def new(name,age):
    print("Name is: ",name)
    print("Age is: ",age)

new(name="Akshay",age=25)
# Out:
# Name is:  Akshay
# Age is:  25

# %% [markdown]
# ##### Arbitrary Arguements (*arg)
#
#     When number of arguements is not known
#     If you do not know how many arguments that will be passed into your function, add a * before the parameter name in the function definition.
#     This way the function will receive a TUPLE of arguments, and can access the items accordingly:
#
#     (*arg)It returns tuple

# %%
def class_students(*name,age=40):
    print(name,age)

class_students("Kamal","Prashant","Nilesh",50)
# Out:
# ('Kamal', 'Prashant', 'Nilesh', 50) 40

# %% [raw]
# def class_students(*name,ag=40):
#     print(name,age)
#
# class_students("Kamal","Prashant","Nilesh",50,ag)
# #Error as ag is not defined in global space

# %%
def class_students(*name,age=40):
    print(name,age)

class_students("Kamal","Prashant","Nilesh",50,age=99)
# Out:
# ('Kamal', 'Prashant', 'Nilesh', 50) 99

# %%
def class_students(*name,age=40):
    print(name,age)

age=77
class_students("Kamal","Prashant","Nilesh",50,age)
# Out:
# ('Kamal', 'Prashant', 'Nilesh', 50, 77) 40

# %%
def class_students(*name):
    for i in name:
        print(i)
#To iterate items of the tuple of arbitrary arguement
class_students("Kamal","Prashant",{200,300})
# Out:
# Kamal
# Prashant
# {200, 300}

# %%
def class_students(salary,*name,city="PUNE"):
    print(salary)
    for i in name:
        print(i)
    print(city)
#To iterate items of the tuple of arbitrary arguement
class_students(202020,"Kamal","Prashant",{200,300})
# Out:
# 202020
# Kamal
# Prashant
# {200, 300}
# PUNE

# %% [markdown]
# #### Arbitrary Keyword arguements (**kwarg)
# -If you do not know how many keyword arguments that will be passed into your function, add two asterisk: ** before the parameter name in the function definition. This way the function will receive a DICTIONARY of arguments, and can access the items accordingly:
#
# (**) It returns dictionary
#
# -Positional arguements always follows after keyword arguement

# %%
def students(name,**details):
    print("name:",name)
    print(details)
    for i,j in details.items():
        print(i,j)
students("dhoni",age=40,city="Ranchi",Country="India") #Sequence matters
# Out:
# name: dhoni
# {'age': 40, 'city': 'Ranchi', 'Country': 'India'}
# age 40
# city Ranchi
# Country India

# %%
def students(*name,aj='ajay',**details):
    print("names are: ",name)
    print("details are: ",details)
    for i,j in details.items():
        print(i,j)
students("dhoni","virat",[100,900],"yuvi",age=40,city="Ranchi",Country="India") #Sequence matters
# Out:
# names are:  ('dhoni', 'virat', [100, 900], 'yuvi')
# details are:  {'age': 40, 'city': 'Ranchi', 'Country': 'India'}
# age 40
# city Ranchi
# Country India

# %%
5
# Out:
# 5
