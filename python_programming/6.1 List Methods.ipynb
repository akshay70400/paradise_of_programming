# %% [markdown]
# # LIST METHODS(attributes)
#     .append(object, /)    -Adding the element at the end of list
#
#     .clear()    -Method removes ALL items/elements from the list,returns EMPTY list
#
#     .count(value)    -Return number of occurrences of value.
#
#     .extend(iterable, /)    -Extend list by appending elements from the iterable.
#
#     .index(value,start,stop)    -It retuns the index of the first matched item
#
#     .remove(value)    -This method removes the FIRST matching element (which is passed as an arguement)
#
#     .pop(index)    -Remove and return item at index (default last (-1)).
#
#     .reverse()    -Method reverses the elmeents of the list(Not descending order)
#
#     .insert(index, object, /)    -Insert object before index.
#
#     .sort(*,key=None,reverse=False)    -makes changes in the original list and does not return anything
#
#     sorted(iterable,key=None,reverse=False)    -does NOT change the list and returns the sorted list
#
#     .copy()    -

# %% [markdown]
# #### append()
# -Adding the element at the end of list
#
#
# -single arguement which will be added at the end

# %%
animal=["cat","dog","rabbit"]
animal.append("cow")
print(animal)
# Out:
# ['cat', 'dog', 'rabbit', 'cow']

# %%
animal=["cat","dog","rabbit"]
animal.append(["black cat", "white cat"])
print(animal)
# Out:
# ['cat', 'dog', 'rabbit', ['black cat', 'white cat']]

# %% [markdown]
# ####  extend()
# -Extend list by appending elements from the iterable.
#
# -Add all elements of a list to the another list
#
# -extend() method modifies the original list. It does not return any value

# %%
animal=["cat","dog","rabbit"]
animal.extend(["black cat", "white cat"])
print(animal)
# Out:
# ['cat', 'dog', 'rabbit', 'black cat', 'white cat']

# %% [markdown]
# #### insert()
# -insert an item before index
#
# -requires: index number and element to be added

# %%
vowel=["a","e","i","u"]

#x=["t","y"]
#vowel.insert(3,"o")

vowel.insert(3,"o")
print(vowel)
# Out:
# ['a', 'e', 'i', 'o', 'u']

# %%
#Does not retun error if indexing out of range
vowel.insert(15,"done")
vowel
# Out:
# ['a', 'e', 'i', 'o', 'u', 'done']

# %%
#if indexing left empty gives error
vowel.insert(0,"ok")
vowel
# Out:
# ['ok', 'a', 'e', 'i', 'o', 'u', 'done']

# %%
vowel.insert(6,["d","f"])
vowel
# Out:
# ['ok', 'a', 'e', 'i', 'o', 'u', ['d', 'f'], ['d', 'f'], 'done']

# %% [markdown]
# #### remove()
# This method removes the FIRST matching element (which is passed as an arguement)

# %%
animal=["cat","dog","rabbit"]

animal.remove("rabbit")
animal
# Out:
# ['cat', 'dog']

# %%
animal=["cat","dog","dog","rabbit"]
animal.remove("dog")
animal
# Out:
# ['cat', 'dog', 'rabbit']

# %%
#Element Can be removed using indexing
animal=["cat","dog","dog","rabbit"]
animal.remove(animal[3])
animal
# Out:
# ['cat', 'dog', 'dog']

# %% [markdown]
# #### pop()
# -removes and returns an element at the given index
#
# -the arguement passed to the method is optional.
#
# -accepts only single arguement
#
# -if not passed, the default index will be -1 which in turns means the last element
#
# -Remove and return item at index (default last).

# %%
lang=["python","java","c++","french","Go Lang"]

lang.pop(1)
print(lang)
# Out:
# ['python', 'c++', 'french', 'Go Lang']

# %%
lang1=["python",".net","java","c++","french","Go Lang"]
lang1.pop() #Defualt is last item
print(lang1)
# Out:
# ['python', '.net', 'java', 'c++', 'french']

# %% [markdown]
# #### del

# %%
lang2=["python",".net","java","c++","french","Go Lang"]
del lang2[0:3]
print(lang2)
# Out:
# ['c++', 'french', 'Go Lang']

# %%
del lang2
print(lang2)

#Here output is : name 'lang2' is not defined
#The list itself gets deleted and variable name becomes undefined
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-47-4008c073ab41> in <module>
# ----> 1 del lang2
#       2 print(lang2)
#
# NameError: name 'lang2' is not defined

# %% [markdown]
# #### clear()
# -Method removes ALL items/elements from the list
#
# -returns EMPTY list

# %%
animal=["cat","dog","dog","rabbit"]
animal.clear()
print(animal)
# Out:
# []

# %%
#emptying list using del
animal4=["cat","dog","dog","rabbit"]
del animal4[:4] 
#or del animal4[0:len(animal4)] 
print(animal4)
# Out:
# []

# %% [markdown]
# #### index()
# -It retuns the index of the first matched item
#
# -index(value,start,stop)
#
# -returns value error if value is not found
#
# -index expected at least 1 argument

# %%
vowels=["a","e","i","o","u"]
vowels.index("i")
# Out:
# 2

# %%
vowels.index("h")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-59-4276dd1a4466> in <module>
# ----> 1 vowels.index("h")
#
# ValueError: 'h' is not in list

# %%
vowels=["a","e","i","o","u","a","e","i","o","u"]
vowels.index("a",1,6)
#1 i.e, Start is inclusive 
#6 i.e, Stop is exclusive
# Out:
# 5

# %% [markdown]
# #### count()
# -returns the count of the no. of items passed as an arguement
#
# -count() takes exactly one argument

# %%
vowels=["a","e","i","o","u","a","e","i","o","u","a"]
vowels.count("a")
# Out:
# 3

# %%
nested_list=[4,2,[1,2,8,9],5,7]
nested_list.count(1)
# Out:
# 0

# %%
nested_list=[4,2,[1,2,8,9],5,7]
nested_list.count(100)
# Out:
# 0

# %% [markdown]
# #### sort() and sorted()
# -sort() makes changes in the original list and does not return anything
#
# -sorted() does NOT change the list and returns the sorted list
#
# -sort/sorted(iterable, /, *, key=None, reverse=False)
#
# -A custom key function can be supplied to customize the sort order, and the
# reverse flag can be set to request the result in descending order.

# %% [raw]
# SORTED Syntax : sorted(iterable, key, reverse)
# Sorted sorts ANY SEQUENCE but always returns a LIST, without modifying the original sequence
#
# Parameters : sorted takes three parameters from which two are optional.
#
# •Iterable : sequence (list, tuple, string) or collection (dictionary, set, frozenset) or any other iterator that needs to be sorted.
#
# •Key(optional) : A function that would server as a key or a basis of sort comparison.
#
# •Reverse(optional) : If set true, then the iterable would be sorted in reverse (descending) order, by default it is set as false

# %%
trial=[3,6,1,9,3,7,5,5,9,6,6,6]

trial.sort()
print("ascending sort:",trial)

trial.sort(reverse=True)
print("descending sort",trial)
# Out:
# ascending sort: [1, 3, 3, 5, 5, 6, 6, 6, 6, 7, 9, 9]
# descending sort [9, 9, 7, 6, 6, 6, 6, 5, 5, 3, 3, 1]

# %%
xyz=[3,6,1,9,3,7,5,5,9,6,6,6]
print(xyz.sort()) #Returns None
print(xyz) #Change in original list
# Out:
# None
# [1, 3, 3, 5, 5, 6, 6, 6, 6, 7, 9, 9]

# %%
xyz1=[3,6,1,9,3,7,5,5,9,6,6,6]
print(sorted(xyz1)) #Retuns ordered list
print(xyz1) #No change in original list
# Out:
# [1, 3, 3, 5, 5, 6, 6, 6, 6, 7, 9, 9]
# [3, 6, 1, 9, 3, 7, 5, 5, 9, 6, 6, 6]

# %%
alphanum=[1,9,6,0,"t","p","s","f"]
alphanum.sort()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-f6b193c81f2b> in <module>
#       1 alphanum=[1,9,6,0,"t","p","s","f"]
# ----> 2 alphanum.sort()
#
# TypeError: '<' not supported between instances of 'str' and 'int'

# %% [markdown]
# #### reverse()
# -method reverses the elmeents of the list(Not descending order)

# %%
trial=[3,6,1,9,3,7,5,5,9,6,6,6]
trial.reverse()
print(trial)

#Usual method for reversing order is - trial[::-1]
# Out:
# [6, 6, 6, 9, 5, 5, 7, 3, 9, 1, 6, 3]

# %% [markdown]
# ### COPYING
#
# = assignment copy
#
#     Gives same id's
#     Change in one varible makes subsequnt change in other variable

# %%
#copy with = gives same id's

players=["virat", "dhoni","yuvi","bhaji"]
runs=["1000","6000","2500","4000"]
new_players=players
print(new_players)

print(id(players))
print(id(new_players))

#Change in one varible makes subsequnt change in other variable
new_players[0]="smith"
print(players) 
print(new_players)
print(id(players))
print(id(new_players))
# Out:
# ['virat', 'dhoni', 'yuvi', 'bhaji']
# 741274573120
# 741274573120
# ['smith', 'dhoni', 'yuvi', 'bhaji']
# ['smith', 'dhoni', 'yuvi', 'bhaji']
# 741274573120
# 741274573120

# %% [markdown]
# The difference between shallow and deep copying is only relevant for compound objects (objects that contain other objects, like lists or class instances):
#
#     •A shallow copy constructs a new compound object and then (to the extent possible) inserts references into it to the objects found in the original.
#
#     •A deep copy constructs a new compound object and then, recursively, inserts copies into it of the objects found in the original.
#
# Two problems often exist with deep copy operations that don’t exist with shallow copy operations:
#
#     •Recursive objects (compound objects that, directly or indirectly, contain a reference to themselves) may cause a recursive loop.
#
#     •Because deep copy copies everything it may copy too much, such as data which is intended to be shared between copies.

# %% [markdown]
# #### copy()   -Shallow copy
# -copy() gives different id's
#
# -Change in one list does not make change in other list
#
# -Concept of shallow copy does not apply to nested list

# %%
players=["virat", "dhoni","yuvi","bhaji"]
new_players=players.copy()
print(players)
print(new_players)
#copying with copy() gives different id's
print(id(players))
print(id(new_players),"\n")
#But elements of both refer to same id's
print(id(players[0]))
print(id(new_players[0]))
# Out:
# ['virat', 'dhoni', 'yuvi', 'bhaji']
# ['virat', 'dhoni', 'yuvi', 'bhaji']
# 495053945600
# 495053944320
#
# 495073162608
# 495073162608

# %%
new_players[1]="kaif"
#Change in one list does not make change in other list
print(players)
print(new_players)
#Post change Id's also different
print(id(players))
print(id(new_players))
#But Id' of individual element(except the changed one) remains same for both
print(id(players[2]))
print(id(new_players[2]))
# Out:
# ['virat', 'dhoni', 'yuvi', 'bhaji']
# ['virat', 'kaif', 'yuvi', 'bhaji']
# 495053945600
# 495053944320
# 495073162736
# 495073162736

# %%
A=[1,2,3]
B=[10,20,30]
C=[A,B]
print(C)

print("A   ",id(A))
print(r"C[0]",id(C[0]),"\n")
print("B   ",id(B))
print(r"C[1]",id(C[1]),"\n")
print("C",id(C))
# Out:
# [[1, 2, 3], [10, 20, 30]]
# A    495053946112
# C[0] 495053946112
#
# B    495053945024
# C[1] 495053945024
#
# C 495053944640

# %%
D=C.copy()
print(D)
D[0][0]="Virat"
'''Concept of shallow copy does not apply to nested list
thereby making changes in both lists if one list is changed'''
print("C :",C,id(C))
print("D :",D,id(D))
# Out:
# [[1, 2, 3], [10, 20, 30]]
# C : [['Virat', 2, 3], [10, 20, 30]] 495053944640
# D : [['Virat', 2, 3], [10, 20, 30]] 495053636224

# %% [markdown]
# #### deepcopy()
# -Different id's
#
# -Makes change in one list only

# %%
import copy

# %%
A=[1,2,3]
B=[10,20,30]
C=[A,B]
print(C)
# Out:
# [[1, 2, 3], [10, 20, 30]]

# %%
D=copy.deepcopy(C)
#Deepcopy gives different Id's
print(id(C))
print(id(D))
print(id(C[0]))
print(id(D[0]))

D[0][0]="yuvi"

print(C)
print(D) 
print(id(C[0][0]))
print(id(D[0][0]))
# Out:
# 495088286400
# 495088244864
# 495077481600
# 495088939648
# [[1, 2, 3], [10, 20, 30]]
# [['yuvi', 2, 3], [10, 20, 30]]
# 140708069582640
# 495073162736

# %%
import copy
x=[1,2,3,4]
x1=[1,2,3,4,5]
y=x.copy()
z=copy.deepcopy(x1)
print("x:",id(x),"x[0]",id(x[0]))
print("y:",id(y),"y[0]",id(y[0]))
print("x1:",id(x1),"x1[0]",id(x1[0]))
print("z:",id(z),"z[0]",id(z[0]))
# Out:
# x: 495088619968 x[0] 140708069582640
# y: 495088619648 y[0] 140708069582640
# x1: 495068647680 x1[0] 140708069582640
# z: 495088610368 z[0] 140708069582640

# %%
y[0]=100
print(x,id(x),id(x[0]))
print(y,id(y),id(y[0]))
# Out:
# [1, 2, 3, 4] 495088257920 140708069582640
# [100, 2, 3, 4] 495089009792 140708069585808

# %%
z[0]=0.1
print(x1,id(x1),id(x1[0]))
print(z,id(z),id(z[0]))
# Out:
# [1, 2, 3, 4, 5] 495068647680 140708069582640
# [0.1, 2, 3, 4, 5] 495088610368 495089834992
