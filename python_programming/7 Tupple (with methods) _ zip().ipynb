# %% [markdown]
# # TUPLE
# -Tuples are used to store multiple items in a single variable. Tuple is one of 4 built-in sequence data types in Python used to store collections of data. A tuple is a collection which is ordered and unchangeable.
#
# -Tuple is somewhat similar to a list
#
# -()round bracket
#
# -Ordered
#
# -Immutable(Unchangeable)
#     -But if tuple contains changeable datatype(ex.list) then that can be changed
#
# -heterogenous/homogenous
#
# -it is used to protect data
#
# -tuples are faster as no manipulation
#
# -it allows duplicate items

# %%
this_is_tuple=("apple",56,3.9,9+8j)
print(this_is_tuple)
type(this_is_tuple)
# Out:
# ('apple', 56, 3.9, (9+8j))
# tuple

# %%
new=("p","y","t","o","n")
new[1]
#new[6] --> Error:indexing out of range
# Out:
# 'y'

# %%
new[::-1]
print(new)
# Out:
# ('p', 'y', 't', 'o', 'n')

# %%
mix=("virat",[1,2,3],[500,700,800])

#mix[0]="dhoni" --> Error: as tuple is immutable

mix[1][1]="yuvi" #list within tuple can be changed
print(mix)

mix[1][0:3]="Dhoni"
print(mix)
# Out:
# ('virat', [1, 'yuvi', 3], [500, 700, 800])
# ('virat', ['D', 'h', 'o', 'n', 'i'], [500, 700, 800])

# %% [markdown]
# #### Negative Indexing

# %%
a=(4,5,6,1,"get")
a[-2]
# Out:
# 1

# %% [markdown]
# #### Slicing

# %%
a=(4,5,6,1,"get")

#slice(stop)
print(a[slice(3)])

#slice(start,stop,step)
print(a[slice(1,3)]) 

print(a[1:-1])
print(a[0:5:2])
print(a) #NOTICE: Original tuple is not altered at all
# Out:
# (4, 5, 6)
# (5, 6)
# (5, 6, 1)
# (4, 6, 'get')
# (4, 5, 6, 1, 'get')

# %% [markdown]
# #### Concatenation of tuple

# %%
a=(4,5,6,1,"get")
b=(7,8,9)
c=(10,11)
d=[155,366,3399]
print(a+b)
print(b+a)
print(b*2)
#print(a+d) --> Error
# Out:
# (4, 5, 6, 1, 'get', 7, 8, 9)
# (7, 8, 9, 4, 5, 6, 1, 'get')
# (7, 8, 9, 7, 8, 9)

# %%
#Tuple item can not be deleted
#Tuple can not be cleared/emptied
#but Whole tuple can be deleted
del c

# %% [markdown]
# #### Packing

# %%
my=3,4.9,"ak"  #this is also tuple
print(my) #Packing
print(type(my))

a,b,c=my #Unpacking
print(a)
print(b)
print(c)
# Out:
# (3, 4.9, 'ak')
# <class 'tuple'>
# 3
# 4.9
# ak

# %%
#single element in () shows its NATIVE datatype
sample=("goat")
print(type(sample))

#@normally Tuple sholud contain more than 1 item
#But single item tuple can also be formed by using following syntax
sample1=("goat",)
print(type(sample1))
len(sample1)
#sample2=(,"goat") --> Invalid syntax
# Out:
# <class 'str'>
# <class 'tuple'>
# 1

# %% [markdown]
# # TUPLE METHODS
#
# -add, change and remove methods not applicable to tuple
#
# -count and index

# %% [markdown]
# #### count()

# %%
my_tuple=(1,5,6,3,4,5,9,6,"6")
print(my_tuple.count(6))
print(my_tuple.count("6"))
# Out:
# 2
# 1

# %% [markdown]
# #### index()

# %%
my_tuple=(1,5,6,3,4,5,9,6,"6")
my_tuple[2]
# Out:
# 6

# %% [markdown]
# ##### Concatenation of two tupples
# t1.__add__(t2)

# %%
tup=(1,2,3,4,5)
tup1=(6,)
tup.__add__(tup1)
# Out:
# (1, 2, 3, 4, 5, 6)

# %% [markdown]
# #### membership

# %%
my_tuple=(1,5,6,3,4,5,9,6,"6")

100 in my_tuple
# Out:
# False

# %%
my_tuple[1] is 5
# Out:
# <>:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <ipython-input-11-f340ddbe2a86>:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   my_tuple[1] is 5
# True

# %% [markdown]
# #### Iterating through a tuple or list

# %%
name=["Virat","dhoni","KL","Shami"]

for x in name:
    print(x)
# Out:
# Virat
# dhoni
# KL
# Shami

# %%
name11=tuple(name)
for i in name11:
    print(i)
# Out:
# Virat
# dhoni
# KL
# Shami

# %% [markdown]
# #### Advantages of Tuple over List
#
# -GENERALLY tuple is used for heterogenous data and list is used for homogenous data (Though both can hold HOMO/HETERO type of data)
#
# -since tuples are IMMUTABLE, so iterating through atuple is FASTER than list
#
# -Tuple that contain immutable elements can be used as DICTIONARY KEY. (not possible in list)
#
# -If you have data that does not change(eg. Passwords) implementing it as tuple will guarantee that remains well PROTECTED
#
# -Consumes LESS MEMORY than list
#
# -Elements BETTER ACCESSED. (In list :Operations like insertion and deletion are better performed.)
#
# -Does not have many built-in methods.(Many built-in methods are available for list)
#
# -Implications of iterations are much faster in tuples.(List: The implication of iterations is time-consuming in the list.)

# %% [markdown]
# ## zip()

# %% [raw]
# The purpose of Python zip() method is to map the similar index of multiple containers so that they can be used just using as single entity.
#
# Syntax :  zip(*iterators)
#
# Parameters :
# Python iterables or containers ( list, string etc )
#
# Return Value :
# Returns a single iterator object, having mapped values from all the
# containers.

# %%
name = [ "Manjeet", "Nikhil", "Shambhavi", "Astha" ]
roll_no = [ 4, 1, 3, 2 ]
marks = [ 40, 50, 60, 70 ]
  
# using zip() to map values
mapped = zip(name, roll_no, marks)
  
mapped = set(mapped)
  
print ("The zipped result is : ",end="")
print (mapped)
# Out:
# The zipped result is : {('Manjeet', 4, 40), ('Astha', 2, 70), ('Shambhavi', 3, 60), ('Nikhil', 1, 50)}

# %% [raw]
# Unzipping means converting the zipped values back to the individual self as they were. This is done with the help of “*” operator.

# %%
# unzipping values
namz, roll_noz, marksz = zip(*mapped)
  
# printing initial lists
print ("The name list is : ",end="")
print (namz)
  
print ("The roll_no list is : ",end="")
print (roll_noz)
  
print ("The marks list is : ",end="")
print (marksz)
# Out:
# The unzipped result:
# The name list is : ('Manjeet', 'Astha', 'Shambhavi', 'Nikhil')
# The roll_no list is : (4, 2, 3, 1)
# The marks list is : (40, 70, 60, 50)
