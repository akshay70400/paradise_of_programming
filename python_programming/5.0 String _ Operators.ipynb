# %% [markdown]
# # STRINGS

# %%
sample_string3 = "Thid is our third string"

len(sample_string3)
# Out:
# 24

# %%
type(sample_string3)
# Out:
# str

# %%
#STRINGS are sequence of characters usually enclosed in single/dpuble/triple quotes
#Strings are IMMUTABLE (can not be changed or deleted)

my_string="data science"
my_string[0]="m"

#Error: 'str' object does not support item assignment
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-255fb07bf122> in <module>
#       3
#       4 my_string="data science"
# ----> 5 my_string[0]="m"
#
# TypeError: 'str' object does not support item assignment

# %%
#But a whole string can be deleted using del function

del my_string

# %% [markdown]
# ### Concatenation of strings

# %%
#to join two strings
#can only concatenate str (not "int") to str
#otherwise errors, unsupported operand type(s) for +: 'int' and 'str'

str1="Data"
str2="science"

result1=str1+str2

print(result1)
# Out:
# Datascience

# %% [markdown]
# ### f string
# -F-strings provide ***A WAY TO EMBED EXPRESSIONS INSIDE STRING LITERALS***, using a minimal syntax. It should be noted that an f-string is really an expression evaluated at run time, not a constant value. In Python source code, an f-string is a literal string, prefixed with f , which contains expressions inside braces.
#
# -***Literals are the constant values assigned to the constant variables.*** We can say that the literals represent the fixed values that cannot be modified. It also contains memory but does not have references as variables. For example, const int =10; is a constant integer expression in which 10 is an integer literal.

# %%
n = 6
for i in range(1,6):
    print("{n}x{i}={n*i}")
# Out:
# {n}x{i}={n*i}
# {n}x{i}={n*i}
# {n}x{i}={n*i}
# {n}x{i}={n*i}
# {n}x{i}={n*i}

# %%
# f string
n = 6
for i in range(1,6):
    print(f"{n}x{i}={n*i}")
# Out:
# 6x1=6
# 6x2=12
# 6x3=18
# 6x4=24
# 6x5=30

# %% [markdown]
# ### ESCAPE SEQUENCING in strings
# -An escape sequence is a sequence of characters that ***does not represent itself*** when used inside a character or string literal.
#
#     \
#     \n
#     \t
#     r

# %%
print("Captain of \"India\" is VIrat")
# Out:
# Captain of "India" is VIrat

# %%
print('''Captain of "India" is VIrat''')
# Out:
# Captain of "India" is VIrat

# %%
print("Captain of \'India\' is \nVIrat")
# Out:
# Captain of 'India' is
# VIrat

# %%
#printing of raw(as it is) string

print(r"Captain of \"India\" is \nVIrat")
# Out:
# Captain of \"India\" is \nVIrat

# %%
print('Captain of "India" is VIrat')
# Out:
# Captain of "India" is VIrat

# %%
print('''Captain of "India" is 'VIrat'.''')
# Out:
# Captain of "India" is 'VIrat'.

# %% [markdown]
# # OPERATORS

# %%
#ARITHMATIC OPERATORS + - / *
#division in default gives float value to avoid loss of data

# %%
x=13
y=5
z=x+y
a=x-y
b=x*y
d=x/y
m=x%y #modulus gives remainder
f=x//y #floor division which removes the fractional part of the division

print("addition=",z,"\n substraction=",a,"\n multiplication=",b,"\n division=",d,"\n modulus=",m)

print("Floor division=",f,"\nExponent=",y**3)

print(type(m))
# Out:
# addition= 18
#  substraction= 8
#  multiplication= 65
#  division= 2.6
#  modulus= 3
# Floor division= 2
# Exponent= 125
# <class 'int'>

# %%
l=198.26
m=12.37
n=l%m
type(n)
# Out:
# float

# %%
l=198.26
m=12.37
n=l//m
type(n)
# Out:
# float

# %% [raw]
# #### COMPARISON OPERATORS
#
# == equal to
#
#
# > greater
#
#
# < lesser
#
#
# >= greater euqal
#
#
# <= lesser equal
#
#
# != Not equal to
#
#
# >+
#
# #this returns True or False

# %%
7>8
# Out:
# False

# %%
5>=4.5
# Out:
# True

# %%
6<=6
# Out:
# True

# %%
5!=5
# Out:
# False

# %%
5!=99
# Out:
# True

# %% [markdown]
# ### LOGICAL OPERATORS

# %%
#and, or, not

# %%
p=True
q=False

p and q
# Out:
# False

# %%
p or q
# Out:
# True

# %%
not q
# Out:
# True

# %% [markdown]
# ### Assignment operator

# %%
v=3
#v=v+5
v+=5
print(v)

# %%
v-=6
print(v)

# %%
n=8
n**=3
print(n)

# %%
n=8
n*=3
print(n)
# Out:
# 24

# %% [markdown]
# ### IDENTITY/MEMBERSHIP OPERATORS:
# is, is not -->identity operator
#
#
# in, not in -->membership operator
#
#
# Both returns True or False

# %%
name="data science is easy"

print("d" in name) #membership operator
print("x" in name)
print("x" not in name)
# Out:
# True
# False
# True

# %%
f=5
g=5

print(f is g) #identity operator
print(f is not g)
# Out:
# True
# False

# %% [markdown]
# ### BITWISE OPERATOR
#
# & ---- Bitwise and
#
# | ----Bitwise OR
#
# ^ ---- Not
#
# ~ ---- Exor

# %%
x=10 
y=4
x|y
# Out:
# 14

# %%
x=10
y=4
x&y
# Out:
# 0

# %%
print(~y)
# Out:
# -5

# %%
q=2
l=2.0
print(q is l)

#2 integer is not eual to 2.0 float

# %% [markdown]
# # Doubt

# %%
a=5
b=5.6

c=print(a+b) 

#this returns NoneType because:
#variable c is not assigned any value yet, because print does not return any value but just prints.

type(c)
# Out:
# 10.6
# NoneType
