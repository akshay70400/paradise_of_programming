# %%
import pandas as pd

dfp=pd.read_csv('C:\\Users\\admin\\Desktop\\Data Science\\Data for ananlysis\\2019 developer survey Stackoverflow\\survey_results_public.csv'\
                     ,index_col='Respondent')

dfs=pd.read_csv('C:\\Users\\admin\\Desktop\\Data Science\\Data for ananlysis\\2019 developer survey Stackoverflow\\survey_results_schema.csv'\
                     ,index_col='Column')

dictionary={
    "first":["Corey","Jane","John"],
    "last":["Schafer","Doe","Doe"],
    "email":["sflajf@gmail","adjhdj@yahoo","adsfasfd@facebook"]
}

dfd=pd.DataFrame(dictionary)

# %% [markdown]
# # 10. Various types of files: excel,xlsx,json,etc

# %%
filt=(dfp['Country']=='India')
india_df=dfp.loc[filt]

# %%
#csv
india_df.to_csv('C:\\Users\\admin\\Desktop\\Data Science\\Data for ananlysis\\2019 developer survey Stackoverflow\\modifiedIndia.csv')

# %%
#tsv
india_df.to_csv('C:\\Users\\admin\\Desktop\\Data Science\\Data for ananlysis\\2019 developer survey Stackoverflow\\modifiedIndia.tsv',sep='\t')

# %%
# !pip install xlwt 
# !pip install openpyxl 
# !pip install xlrd

# %%
india_df.to_excel('C:\\Users\\admin\\Desktop\\Data Science\\Data for ananlysis\\2019 developer survey Stackoverflow\\modifiedIndia.xlsx')

# %%
test=pd.read_excel('C:\\Users\\admin\\Desktop\\Data Science\\Data for ananlysis\\2019 developer survey Stackoverflow\\modifiedIndia.xlsx',index_col='Respondent')
test.head()
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 8                      I code primarily as a hobby      Yes
# 10                  I am a developer by profession      Yes
# 15          I am a student who is learning to code      Yes
# 50                  I am a developer by profession      Yes
# 65                  I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 8              Less than once per year
# 10          Once a month or more often
# 15                               Never
# 50          Once a month or more often
# 65                               Never
#
#                                                    OpenSource  \
# Respondent
# 8           OSS is, on average, of HIGHER quality than pro...
# 10          OSS is, on average, of HIGHER quality than pro...
# 15          OSS is, on average, of HIGHER quality than pro...
# 50          OSS is, on average, of LOWER quality than prop...
# ...

# %%
india_df.to_json('C:\\Users\\admin\\Desktop\\Data Science\\Data for ananlysis\\2019 developer survey Stackoverflow\\modifiedIndia.json')
#by default its dictionarylike

# %%
india_df.to_json('C:\\Users\\admin\\Desktop\\Data Science\\Data for ananlysis\\2019 developer survey Stackoverflow\\modifiedIndia.json',orient='records',lines=True)
#this json is list like

# %%
test=pd.read_json('C:\\Users\\admin\\Desktop\\Data Science\\Data for ananlysis\\2019 developer survey Stackoverflow\\modifiedIndia.json',orient='records',lines=True)
test.head()
# Out:
#                                MainBranch Hobbyist  \
# 0             I code primarily as a hobby      Yes
# 1          I am a developer by profession      Yes
# 2  I am a student who is learning to code      Yes
# 3          I am a developer by profession      Yes
# 4          I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0     Less than once per year
# 1  Once a month or more often
# 2                       Never
# 3  Once a month or more often
# 4                       Never
#
#                                           OpenSource  \
# 0  OSS is, on average, of HIGHER quality than pro...
# 1  OSS is, on average, of HIGHER quality than pro...
# 2  OSS is, on average, of HIGHER quality than pro...
# 3  OSS is, on average, of LOWER quality than prop...
# 4                                               None
#
#                            Employment Country         Student  \
# 0  Not employed, but looking for work   India            None
# ...

# %%
# !pip install SQLAlchemy

# %%
# !pip install psychopg2-binary
# Out:
# ERROR: Could not find a version that satisfies the requirement psychopg2-binary
# ERROR: No matching distribution found for psychopg2-binary

# %% [markdown]
# # 9. Date Objects in DataFrame
